# %%
# %%!pip install cloudscraper -U
import cloudscraper
import requests
import json
from io import StringIO as sio
import pandas as pd
from bs4 import BeautifulSoup as bs
headers={
    "User-Agent":"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4437.0 Safari/537.36 Edg/91.0.831.1",
    "Accept": "application/json, text/plain, */*",}

# %%
scraper = cloudscraper.create_scraper()

# %%
report_url="https://nepsealpha.com/financials-reports?fiscal_year=078-079&quater=1&symbol="
financial_url="https://nepsealpha.com/ajax/financials-menu/{}"
w_season_url="https://nepsealpha.com/seasonality/weekly/{}"
m_season_url="https://nepsealpha.com/seasonality/monthly/{}"
compare_url="https://nepsealpha.com/financials-screener/ajax?symbol_a=NICA&fiscal_year_a=77078&quater_a=3&symbol_b=NABIL&fiscal_year_b=77078&quater_b=3"
mf_list_url="https://nepsealpha.com/mutual-fund-navs"
mf_holding_url="https://nepsealpha.com/mutual-fund-navs/{}"

# %%
resp=scraper.get(mf_list_url,headers=headers).text

# %%
soup=bs(resp,"html.parser")
preloader = soup.find("div", id="preloader")
if preloader:
    preloader.decompose()
finder=soup.div
data=finder.get('data-page')

# %%
props=json.loads(data)["props"]
mflist=pd.DataFrame(props["navs_trends"])
mflist["created_at"]=mflist["created_at"].str[:10]
mflist["updated_at"]=mflist["updated_at"].str[:10]
mflist.set_index("symbol",inplace=True)

# %%
mflist1=pd.concat([mflist,pd.DataFrame.from_dict(props["pe_ratios"],orient="index")],axis=1)

# %%
mflist.rename(columns={mflist.columns[-1]: "pe_ratio"}, inplace=True)

# %%
def get_holding(symbol):
  holding_raw=scraper.get(mf_holding_url.format(symbol),headers=headers)
  df=pd.read_html(sio(holding_raw.text))[0]
  df["mf"]=symbol
  return df
df1=pd.DataFrame()

# %%
for ind in mflist.index:
  df1=pd.concat([df1,get_holding(ind)])
df1.to_csv("Mutual fund holding/"+df1.iloc[0,2],index=False)

# %%
mflist
# Out:
#          id                                     name       type total_paid_up  \
# symbol
# NICGF2   50                   Nic Asia Growth Fund 2  Close End    1500000000
# NIBLSF   19                    NIBL Sahabhagita Fund   Open End    5174877430
# SBCF     23                    Sunrise Bluechip Fund  Close End    1250000000
# LVF2     48                       Laxmi Value Fund 2  Close End     800000000
# CMF2     13                   CITIZENS MUTUAL FUND 2  Close End     560000000
# SFMF     17                Sunrise First Mutual Fund  Close End     860000000
# SAGF     40                       Sanima Growth Fund  Close End     672532600
# C30MF    47            Citizens Super 30 Mutual Fund  Close End     750723900
# NMBSBF   29                NMB Saral Bachat Fund - E   Open End  2541080007.9
# NFCF     39                     Nabil Flexi Cap Fund   Open End     850035630
# LUK      18                        Laxmi Unnati Kosh  Close End     652623600
# NICBF    16                   NIC Asia Balanced Fund  Close End     755000000
# NMB50    14                                   NMB 50  Close End    1250000000
# NICGF2       {'symbol': 'NICGF2', 'today_price': '9'}
# NIBLSF    {'symbol': 'NIBLSF', 'today_price': '10.9'}
# SBCF         {'symbol': 'SBCF', 'today_price': '9.1'}
# LVF2         {'symbol': 'LVF2', 'today_price': '9.2'}
# CMF2        {'symbol': 'CMF2', 'today_price': '9.28'}
# SFMF          {'symbol': 'SFMF', 'today_price': '10'}
# SAGF        {'symbol': 'SAGF', 'today_price': '9.17'}
# C30MF       {'symbol': 'C30MF', 'today_price': '8.9'}
# NMBSBF   {'symbol': 'NMBSBF', 'today_price': '10.45'}
# NFCF       {'symbol': 'NFCF', 'today_price': '11.17'}
# LUK          {'symbol': 'LUK', 'today_price': '9.72'}
# NICBF      {'symbol': 'NICBF', 'today_price': '9.17'}
# NMB50     {'symbol': 'NMB50', 'today_price': '10.03'}
# GIBF1       {'symbol': 'GIBF1', 'today_price': '9.7'}
# RMF1        {'symbol': 'RMF1', 'today_price': '8.96'}
# SIGS2       {'symbol': 'SIGS2', 'today_price': '9.6'}
# NICFC      {'symbol': 'NICFC', 'today_price': '9.14'}
# NBF3         {'symbol': 'NBF3', 'today_price': '9.1'}
# KSY          {'symbol': 'KSY', 'today_price': '8.45'}
# NIBSF2     {'symbol': 'NIBSF2', 'today_price': '8.4'}
# KSLY       {'symbol': 'KSLY', 'today_price': '11.28'}
# SIGS3      {'symbol': 'SIGS3', 'today_price': '9.56'}
# SSIS       {'symbol': 'SSIS', 'today_price': '10.77'}
# NSIF2     {'symbol': 'NSIF2', 'today_price': '10.26'}
# SFEF        {'symbol': 'SFEF', 'today_price': '9.07'}
# KDBY        {'symbol': 'KDBY', 'today_price': '9.48'}
# KEF          {'symbol': 'KEF', 'today_price': '8.88'}
# NIBLSTF  {'symbol': 'NIBLSTF', 'today_price': '8.45'}
# SEF          {'symbol': 'SEF', 'today_price': '9.56'}
# SLK         {'symbol': 'SLK', 'today_price': '11.06'}
# PSF         {'symbol': 'PSF', 'today_price': '10.08'}
# RMF2        {'symbol': 'RMF2', 'today_price': '9.14'}
# PRSF        {'symbol': 'PRSF', 'today_price': '9.88'}
# NBF2        {'symbol': 'NBF2', 'today_price': '9.18'}
# NICGF     {'symbol': 'NICGF', 'today_price': '10.57'}
# MMF1        {'symbol': 'MMF1', 'today_price': '8.77'}
# SLCF        {'symbol': 'SLCF', 'today_price': '9.24'}
# NADDF     {'symbol': 'NADDF', 'today_price': '10.37'}
# MNMF1       {'symbol': 'MNMF1', 'today_price': '9.3'}
# CMF1        {'symbol': 'CMF1', 'today_price': '10.7'}
# NICSF      {'symbol': 'NICSF', 'today_price': '9.65'}
# NIBLGF    {'symbol': 'NIBLGF', 'today_price': '8.51'}
# H8020     {'symbol': 'H8020', 'today_price': '10.05'}
